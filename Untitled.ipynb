# %%
import numpy
import pandas
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.python.keras.layers import ConvLSTM2D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time

# %%
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-IMF1.csv', usecols=[0,1,2,3,4,5,6], engine='python')
# print(dataframe)
#print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
print(dataset)
# Out:
# [[ 1.4983014e+00  9.4074722e+01 -1.1876233e+01 ... -5.6182855e+02
#   -2.9530383e+02 -2.6579716e+01]
#  [-1.3245347e+00  5.4141308e+01  1.4498167e+02 ... -1.8682271e+02
#    8.8286331e+01 -4.8768269e+01]
#  [-1.2420310e-01  8.1667862e+01  6.0397418e+02 ...  4.0662903e+02
#    3.9066507e+02  2.3082651e+01]
#  ...
#  [ 1.2442022e-01 -2.2749472e+02  1.1829082e+03 ...  1.4146246e+02
#   -3.9959131e+02  3.9486243e+02]
#  [ 9.8921861e-03 -5.7551752e+02  2.3119507e+03 ... -1.1121912e+02
#    3.8677768e+02  1.1874208e+02]
#  [ 1.7314582e-01 -2.4544824e+02  3.2707751e+03 ... -2.2669441e+02
#    4.3053912e+02 -5.8661511e+02]]

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
a = dataset[0:(0+2), 0:2]
print(a)
# Out:
# [[ 1.4983014 94.07472  ]
#  [-1.3245347 54.141308 ]]

# %%
print(dataset.shape[1])
# Out:
# 7
