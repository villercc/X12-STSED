# %%
#ConvLSTM  univariate
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.python.keras.layers import ConvLSTM2D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time
# fix random seed for reproducibility
np.random.seed(7)

start = time.time()


# load the dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', usecols=[0], engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)


#数据缩放 
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#print(X_scaler)
#print(Y_scaler)
#print(Y)


# 将数据拆分成训练和测试=========0.78 or 0.89
train_size = int(len(dataset) * 0.89)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX)
#print(trainY)
#print(testX)
#print(testY)



#重构数据集
##timestep为时间步长
def create_dataset(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep])
    return np.array(dataX), np.array(dataY)



#----------forecasting-----------
timestep = 6
dim = 1
pres=[]
trainX,trainY = create_dataset(train, timestep)
testX,testY = create_dataset(test, timestep) 
print("转为监督学习，训练集数据长度：", len(trainX))
#print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
#print(testX, testY )


# 数据重构为5D [samples, timesteps, rows, columns, features]
trainX_input5D = np.reshape(trainX, (trainX.shape[0], 2,1,timestep//2, dim))
testX_input5D = np.reshape(testX, (testX.shape[0],2,1,timestep//2, dim))
#trainX_input5D = np.reshape(trainX, (trainX.shape[0], timestep,1,1, dim))
#testX_input5D = np.reshape(testX, (testX.shape[0],timestep, 1,1, dim))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input5D.shape,testX_input5D.shape)


# create and fit the convlstm network
if __name__ == '__main__':
    model = Sequential()
    model.add(ConvLSTM2D(filters=48, kernel_size=(1,2), activation='relu', 
#                         input_shape=(timestep, 1,1, dim),
                         input_shape=(2,1,timestep//2, dim),
                         padding='same', return_sequences=True))
    model.add(ConvLSTM2D(filters=24, kernel_size=(2,1), activation='relu',
                         padding='same', return_sequences=True))
    
    #model.add(Dropout(0.1))
    model.add(Flatten())
    model.add(Dense(1))

    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input5D, trainY, epochs=1000)

    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input5D)
    testPredict = model.predict(testX_input5D)

    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))

# %%
#CNN
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import TimeDistributed
from tensorflow.python.keras.layers.convolutional import Conv1D
from tensorflow.python.keras.layers.convolutional import MaxPooling1D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()


# load the dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)


#数据缩放 
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#print(X_scaler)
#print(Y_scaler)
#print(Y)


# 将数据拆分成训练和测试，7.8/9作为训练数据
train_size = int(len(dataset) * 0.89)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX)
#print(trainY)
#print(testX)
#print(testY)



#重构数据集
##timestep为时间步长
def create_dataset(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep])
    return np.array(dataX), np.array(dataY)



#----------forecasting-----------
timestep = 6
dim = 1
pres=[]
trainX,trainY = create_dataset(train, timestep)
testX,testY = create_dataset(test, timestep) 
print("转为监督学习，训练集数据长度：", len(trainX))
#print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
#print(testX, testY )


# 数据重构为4D [samples, subsequences, timesteps, features]
trainX_input4D = np.reshape(trainX, (trainX.shape[0],1,timestep,dim))
testX_input4D = np.reshape(testX, (testX.shape[0],1,timestep,dim))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input4D.shape,testX_input4D.shape)


# create and fit the convlstm network
if __name__ == '__main__':
    model = Sequential()
    model.add(TimeDistributed(Conv1D(filters=48, kernel_size=1, activation='relu', input_shape=(None,1, testX.shape[1]))))
    model.add(TimeDistributed(MaxPooling1D(pool_size=1)))
    model.add(TimeDistributed(Flatten()))

    #model.add(LSTM(4,activation='relu'))
    model.add(Dense(1))

    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input4D, trainY, epochs=1000)
    


    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input4D)
    testPredict = model.predict(testX_input4D)


    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/cnnoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/cnnEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))
# Out:
# 数据集的长度： 324
# 原始训练集的长度： 288
# 原始测试集的长度： 36
# 转为监督学习，训练集数据长度： 282
# 转为监督学习，测试集数据长度： 30
# 构造得到模型的输入数据(训练数据已有标签trainY):  (282, 1, 6, 1) (30, 1, 6, 1)
# Train on 282 samples
# Epoch 1/1000
# 282/282 [==============================] - 1s 2ms/sample - loss: 0.4050
# Epoch 2/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.2460
# Epoch 3/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.1305
# Epoch 4/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0581
# Epoch 5/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0227
# Epoch 6/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0132
# Epoch 7/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0126
# Epoch 8/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0120
# Epoch 9/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0106
# Epoch 10/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0099
# Epoch 11/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0093
# Epoch 12/1000
# 282/282 [==============================] - ETA: 0s - loss: 0.009 - 0s 88us/sample - loss: 0.0087
# Epoch 13/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0082
# Epoch 14/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0077
# Epoch 15/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0073
# Epoch 16/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0068
# Epoch 17/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0065
# Epoch 18/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0061
# Epoch 19/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0058
# Epoch 20/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0056
# Epoch 21/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0053
# Epoch 22/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0051
# Epoch 23/1000
# 282/282 [==============================] - 0s 50us/sample - loss: 0.0050
# Epoch 24/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0048
# Epoch 25/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0047
# Epoch 26/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0046
# Epoch 27/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0045
# Epoch 28/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0044
# Epoch 29/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0043
# Epoch 30/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0043
# Epoch 31/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0042
# Epoch 32/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0042
# Epoch 33/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0041
# Epoch 34/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0041
# Epoch 35/1000
# 282/282 [==============================] - 0s 49us/sample - loss: 0.0041
# Epoch 36/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0041
# Epoch 37/1000
# 282/282 [==============================] - 0s 46us/sample - loss: 0.0040
# Epoch 38/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0040
# Epoch 39/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0040
# Epoch 40/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0040
# Epoch 41/1000
# 282/282 [==============================] - 0s 46us/sample - loss: 0.0040
# Epoch 42/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0039
# Epoch 43/1000
# 282/282 [==============================] - 0s 50us/sample - loss: 0.0039
# Epoch 44/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0039
# Epoch 45/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0039
# Epoch 46/1000
# 282/282 [==============================] - ETA: 0s - loss: 0.003 - 0s 67us/sample - loss: 0.0039
# Epoch 47/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0039
# Epoch 48/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0038
# Epoch 49/1000
# 282/282 [==============================] - 0s 46us/sample - loss: 0.0038
# Epoch 50/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0038
# Epoch 51/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0038
# Epoch 52/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0038
# Epoch 53/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0038
# Epoch 54/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0037
# Epoch 55/1000
# 282/282 [==============================] - 0s 99us/sample - loss: 0.0037
# Epoch 56/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0037
# Epoch 57/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0037
# Epoch 58/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0037
# Epoch 59/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0037
# Epoch 60/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0036
# Epoch 61/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0036
# Epoch 62/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0036
# Epoch 63/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0036
# Epoch 64/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0036
# Epoch 65/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0036
# Epoch 66/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0035
# Epoch 67/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0035
# Epoch 68/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0035
# Epoch 69/1000
# 282/282 [==============================] - 0s 88us/sample - loss: 0.0035
# Epoch 70/1000
# 282/282 [==============================] - 0s 85us/sample - loss: 0.0035
# Epoch 71/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0035
# Epoch 72/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0035
# Epoch 73/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0034
# Epoch 74/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0034
# Epoch 75/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0034
# Epoch 76/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0034
# Epoch 77/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0034
# Epoch 78/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0033
# Epoch 79/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0033
# Epoch 80/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0033
# Epoch 81/1000
# 282/282 [==============================] - 0s 95us/sample - loss: 0.0033
# Epoch 82/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0033
# Epoch 83/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0033
# Epoch 84/1000
# 282/282 [==============================] - 0s 85us/sample - loss: 0.0032
# Epoch 85/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0033
# Epoch 86/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0032
# Epoch 87/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0032
# Epoch 88/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0032
# Epoch 89/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0032
# Epoch 90/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0031
# Epoch 91/1000
# 282/282 [==============================] - 0s 88us/sample - loss: 0.0032
# Epoch 92/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0031
# Epoch 93/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0031
# Epoch 94/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0031
# Epoch 95/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0031
# Epoch 96/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0031
# Epoch 97/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0030
# Epoch 98/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0030
# Epoch 99/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0030
# Epoch 100/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0030
# Epoch 101/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0030
# Epoch 102/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0029
# Epoch 103/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0029
# Epoch 104/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0029
# Epoch 105/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0029
# Epoch 106/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0029
# Epoch 107/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0029
# Epoch 108/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0029
# Epoch 109/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0028
# Epoch 110/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0028
# Epoch 111/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0028
# Epoch 112/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0028
# Epoch 113/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0028
# Epoch 114/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0028
# Epoch 115/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0027
# Epoch 116/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 117/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0027
# Epoch 118/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 119/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 120/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 121/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 122/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0027
# Epoch 123/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0027
# Epoch 124/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0026
# Epoch 125/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0026
# Epoch 126/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0026
# Epoch 127/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0026
# Epoch 128/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0025
# Epoch 129/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0025
# Epoch 130/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0025
# Epoch 131/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0025
# Epoch 132/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0025
# Epoch 133/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0025
# Epoch 134/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0025
# Epoch 135/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0024
# Epoch 136/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0024
# Epoch 137/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0024
# Epoch 138/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0024
# Epoch 139/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0024
# Epoch 140/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0024
# Epoch 141/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0024
# Epoch 142/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0023
# Epoch 143/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0023
# Epoch 144/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0023
# Epoch 145/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0023
# Epoch 146/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0023
# Epoch 147/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0023
# Epoch 148/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0023
# Epoch 149/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0023
# Epoch 150/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0022
# Epoch 151/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0022
# Epoch 152/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0022
# Epoch 153/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0022
# Epoch 154/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0022
# Epoch 155/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0022
# Epoch 156/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0022
# Epoch 157/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0022
# Epoch 158/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 159/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0021
# Epoch 160/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0021
# Epoch 161/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 162/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 163/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 164/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 165/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0021
# Epoch 166/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0021
# Epoch 167/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0020
# Epoch 168/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0020
# Epoch 169/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0020
# Epoch 170/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0020
# Epoch 171/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 172/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 173/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0020
# Epoch 174/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 175/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 176/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0020
# Epoch 177/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0019
# Epoch 178/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0019
# Epoch 179/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 180/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0020
# Epoch 181/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0019
# Epoch 182/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0019
# Epoch 183/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0019
# Epoch 184/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0019
# Epoch 185/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0019
# Epoch 186/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0019
# Epoch 187/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0018
# Epoch 188/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0018
# Epoch 189/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0019
# Epoch 190/1000
# 282/282 [==============================] - 0s 81us/sample - loss: 0.0018
# Epoch 191/1000
# 282/282 [==============================] - 0s 78us/sample - loss: 0.0018
# Epoch 192/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0018
# Epoch 193/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0018
# Epoch 194/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0018
# Epoch 195/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0018
# Epoch 196/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0018
# Epoch 197/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0018
# Epoch 198/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0017
# Epoch 199/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0018
# Epoch 200/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 201/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 202/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 0.0017
# Epoch 203/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0017
# Epoch 204/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 205/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 206/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 207/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0018
# Epoch 208/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 209/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 210/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0017
# Epoch 211/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0017
# Epoch 212/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0017
# Epoch 213/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0016
# Epoch 214/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0016
# Epoch 215/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0016
# Epoch 216/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0016
# Epoch 217/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0016
# Epoch 218/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0016
# Epoch 219/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0016
# Epoch 220/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0016
# Epoch 221/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0016
# Epoch 222/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0016
# Epoch 223/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0016
# Epoch 224/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0016
# Epoch 225/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0016
# Epoch 226/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0016
# Epoch 227/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0015
# Epoch 228/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0016
# Epoch 229/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0015
# Epoch 230/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 231/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 232/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 233/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 234/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 235/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 236/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 237/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 238/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 239/1000
# 282/282 [==============================] - 0s 88us/sample - loss: 0.0015
# Epoch 240/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0015
# Epoch 241/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 242/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0015
# Epoch 243/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 244/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 245/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0015
# Epoch 246/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0015
# Epoch 247/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 248/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 249/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 250/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 251/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0015
# Epoch 252/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 253/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0014
# Epoch 254/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 255/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 256/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0015
# Epoch 257/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 258/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0014
# Epoch 259/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 260/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 261/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0014
# Epoch 262/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 263/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 264/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 265/1000
# 282/282 [==============================] - 0s 103us/sample - loss: 0.0014
# Epoch 266/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 267/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 0.0014
# Epoch 268/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0015
# Epoch 269/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 270/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0013
# Epoch 271/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 272/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0013
# Epoch 273/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 274/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 275/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 276/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 277/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0014
# Epoch 278/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0014
# Epoch 279/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0014
# Epoch 280/1000
# 282/282 [==============================] - 0s 134us/sample - loss: 0.0013
# Epoch 281/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0013
# Epoch 282/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0013
# Epoch 283/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 284/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 285/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0013
# Epoch 286/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 287/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 288/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 289/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 290/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0013
# Epoch 291/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0013
# Epoch 292/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 293/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0013
# Epoch 294/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 295/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 296/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 297/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 298/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 299/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 300/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 301/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 302/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 303/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 304/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 305/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 306/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0013
# Epoch 307/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 308/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 309/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 310/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 311/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0012
# Epoch 312/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 313/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 314/1000
# 282/282 [==============================] - 0s 88us/sample - loss: 0.0012
# Epoch 315/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 316/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 317/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 318/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0013
# Epoch 319/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 320/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 321/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 322/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 323/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 324/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 325/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 326/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 327/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 328/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 329/1000
# 282/282 [==============================] - ETA: 0s - loss: 7.0388e-0 - 0s 60us/sample - loss: 0.0012
# Epoch 330/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 331/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 332/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 333/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 334/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 335/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 336/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 337/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 338/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 339/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 340/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 341/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 342/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0011
# Epoch 343/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 344/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0011
# Epoch 345/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0011
# Epoch 346/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 347/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 348/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 349/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 350/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 351/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 352/1000
# 282/282 [==============================] - ETA: 0s - loss: 8.1590e-0 - 0s 57us/sample - loss: 0.0012
# Epoch 353/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 354/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 355/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 356/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 357/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 358/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0011
# Epoch 359/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0012
# Epoch 360/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0011
# Epoch 361/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0012
# Epoch 362/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 363/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 364/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 365/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 366/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0012
# Epoch 367/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 368/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 369/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 370/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0011
# Epoch 371/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0011
# Epoch 372/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 373/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 374/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 375/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 376/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0011
# Epoch 377/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 378/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 379/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 380/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 381/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0011
# Epoch 382/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 383/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 384/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 385/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0012
# Epoch 386/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 387/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 388/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 389/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 390/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 391/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 392/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 393/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 394/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 395/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 396/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 397/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 398/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 399/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 400/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 401/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 402/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 403/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 404/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 405/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 406/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 407/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0011
# Epoch 408/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 409/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 410/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 411/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 412/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 413/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 414/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.8860e-04
# Epoch 415/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 416/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 417/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 418/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 0.0010
# Epoch 419/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 420/1000
# 282/282 [==============================] - ETA: 0s - loss: 6.1372e-0 - 0s 64us/sample - loss: 0.0011
# Epoch 421/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 422/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 423/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 424/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 0.0010
# Epoch 425/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 426/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 427/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 9.9220e-04
# Epoch 428/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 429/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 430/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 431/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 432/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 433/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 434/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 435/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 436/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 0.0010
# Epoch 437/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.8191e-04
# Epoch 438/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.8729e-04
# Epoch 439/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6913e-04
# Epoch 440/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.7551e-04
# Epoch 441/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.8161e-04
# Epoch 442/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.7178e-04
# Epoch 443/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.9956e-04
# Epoch 444/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 445/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.9225e-04
# Epoch 446/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.6816e-04
# Epoch 447/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.7837e-04
# Epoch 448/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 9.7358e-04
# Epoch 449/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.7601e-04
# Epoch 450/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6426e-04
# Epoch 451/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6422e-04
# Epoch 452/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.5643e-04
# Epoch 453/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 454/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.7037e-04
# Epoch 455/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4077e-04
# Epoch 456/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 457/1000
# 282/282 [==============================] - ETA: 0s - loss: 6.9954e-0 - 0s 78us/sample - loss: 9.3366e-04
# Epoch 458/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.5237e-04
# Epoch 459/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 460/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4563e-04
# Epoch 461/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.3922e-04
# Epoch 462/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 9.7116e-04
# Epoch 463/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.5247e-04
# Epoch 464/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4317e-04
# Epoch 465/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2623e-04
# Epoch 466/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 9.4616e-04
# Epoch 467/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.3034e-04
# Epoch 468/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6600e-04
# Epoch 469/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4905e-04
# Epoch 470/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.3492e-04
# Epoch 471/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6975e-04
# Epoch 472/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.3324e-04
# Epoch 473/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 9.9486e-04
# Epoch 474/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4778e-04
# Epoch 475/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2378e-04
# Epoch 476/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4156e-04
# Epoch 477/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.3401e-04
# Epoch 478/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.5296e-04
# Epoch 479/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2966e-04
# Epoch 480/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2238e-04
# Epoch 481/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4492e-04
# Epoch 482/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.2413e-04
# Epoch 483/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2823e-04
# Epoch 484/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.3444e-04
# Epoch 485/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.4067e-04
# Epoch 486/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.2441e-04
# Epoch 487/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 488/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 9.0011e-04
# Epoch 489/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.0733e-04
# Epoch 490/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.1046e-04
# Epoch 491/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.3170e-04
# Epoch 492/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.9839e-04
# Epoch 493/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 8.9407e-04
# Epoch 494/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.4079e-04
# Epoch 495/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.1873e-04
# Epoch 496/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.0044e-04
# Epoch 497/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.9740e-04
# Epoch 498/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 9.0127e-04
# Epoch 499/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.0424e-04
# Epoch 500/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 8.9486e-04
# Epoch 501/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.8997e-04
# Epoch 502/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.0490e-04
# Epoch 503/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.9922e-04
# Epoch 504/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.4466e-04
# Epoch 505/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 8.8284e-04
# Epoch 506/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.7847e-04
# Epoch 507/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.8676e-04
# Epoch 508/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.3193e-04
# Epoch 509/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.9715e-04
# Epoch 510/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.5419e-04
# Epoch 511/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.8602e-04
# Epoch 512/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.9209e-04
# Epoch 513/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.0226e-04
# Epoch 514/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0011
# Epoch 515/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.4458e-04
# Epoch 516/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.6182e-04
# Epoch 517/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.9943e-04
# Epoch 518/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.2688e-04
# Epoch 519/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.5668e-04
# Epoch 520/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 0.0010
# Epoch 521/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.7336e-04
# Epoch 522/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 9.0782e-04
# Epoch 523/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.2252e-04
# Epoch 524/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.8990e-04
# Epoch 525/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.6674e-04
# Epoch 526/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.6096e-04
# Epoch 527/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 8.6756e-04
# Epoch 528/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.4283e-04
# Epoch 529/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 0.0010
# Epoch 530/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 9.3290e-04
# Epoch 531/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.9503e-04
# Epoch 532/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 8.7038e-04
# Epoch 533/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.5884e-04
# Epoch 534/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 8.7736e-04
# Epoch 535/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.9390e-04
# Epoch 536/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 8.9079e-04
# Epoch 537/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.6606e-04
# Epoch 538/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 9.0111e-04
# Epoch 539/1000
# ...
# Epoch 840/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.2162e-04
# Epoch 841/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3309e-04
# Epoch 842/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9286e-04
# Epoch 843/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.0482e-04
# Epoch 844/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.9253e-04
# Epoch 845/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9632e-04
# Epoch 846/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.4688e-04
# Epoch 847/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1236e-04
# Epoch 848/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2916e-04
# Epoch 849/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 7.3576e-04
# Epoch 850/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.1833e-04
# Epoch 851/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0669e-04
# Epoch 852/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2249e-04
# Epoch 853/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0818e-04
# Epoch 854/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.0833e-04
# Epoch 855/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9994e-04
# Epoch 856/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9546e-04
# Epoch 857/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1199e-04
# Epoch 858/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.4341e-04
# Epoch 859/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 7.4118e-04
# Epoch 860/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0777e-04
# Epoch 861/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8614e-04
# Epoch 862/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.0820e-04
# Epoch 863/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.0261e-04
# Epoch 864/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9446e-04
# Epoch 865/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8361e-04
# Epoch 866/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9153e-04
# Epoch 867/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0553e-04
# Epoch 868/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0049e-04
# Epoch 869/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.5347e-04
# Epoch 870/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2612e-04
# Epoch 871/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.8977e-04
# Epoch 872/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2726e-04
# Epoch 873/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.0136e-04
# Epoch 874/1000
# 282/282 [==============================] - 0s 73us/sample - loss: 7.6465e-04
# Epoch 875/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8461e-04
# Epoch 876/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.2193e-04
# Epoch 877/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.8657e-04
# Epoch 878/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.3225e-04
# Epoch 879/1000
# 282/282 [==============================] - ETA: 0s - loss: 0.001 - 0s 57us/sample - loss: 7.1434e-04
# Epoch 880/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.5960e-04
# Epoch 881/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 9.2667e-04
# Epoch 882/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.3550e-04
# Epoch 883/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3514e-04
# Epoch 884/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.1202e-04
# Epoch 885/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.2827e-04
# Epoch 886/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9769e-04
# Epoch 887/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3051e-04
# Epoch 888/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.9762e-04
# Epoch 889/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1120e-04
# Epoch 890/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9628e-04
# Epoch 891/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.1063e-04
# Epoch 892/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.9725e-04
# Epoch 893/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.8844e-04
# Epoch 894/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1042e-04
# Epoch 895/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.7834e-04
# Epoch 896/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8058e-04
# Epoch 897/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9815e-04
# Epoch 898/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9806e-04
# Epoch 899/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.8353e-04
# Epoch 900/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8482e-04
# Epoch 901/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8929e-04
# Epoch 902/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.0302e-04
# Epoch 903/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.0645e-04
# Epoch 904/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.1000e-04
# Epoch 905/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.1970e-04
# Epoch 906/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.9430e-04
# Epoch 907/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.1289e-04
# Epoch 908/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9054e-04
# Epoch 909/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9584e-04
# Epoch 910/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.1740e-04
# Epoch 911/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.7651e-04
# Epoch 912/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8199e-04
# Epoch 913/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1000e-04
# Epoch 914/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.8265e-04
# Epoch 915/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.5802e-04
# Epoch 916/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8854e-04
# Epoch 917/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9199e-04
# Epoch 918/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.1752e-04
# Epoch 919/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1810e-04
# Epoch 920/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.0185e-04
# Epoch 921/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.8357e-04
# Epoch 922/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0308e-04
# Epoch 923/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8255e-04
# Epoch 924/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8545e-04
# Epoch 925/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.0760e-04
# Epoch 926/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.4678e-04
# Epoch 927/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8880e-04
# Epoch 928/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.3465e-04
# Epoch 929/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.1793e-04
# Epoch 930/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8146e-04
# Epoch 931/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.8737e-04
# Epoch 932/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.7684e-04
# Epoch 933/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.7672e-04
# Epoch 934/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.2793e-04
# Epoch 935/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.6922e-04
# Epoch 936/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.6007e-04
# Epoch 937/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.4249e-04
# Epoch 938/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.6308e-04
# Epoch 939/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9344e-04
# Epoch 940/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0847e-04
# Epoch 941/1000
# 282/282 [==============================] - 0s 53us/sample - loss: 7.7094e-04
# Epoch 942/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.0174e-04
# Epoch 943/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.1702e-04
# Epoch 944/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.7789e-04
# Epoch 945/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9251e-04
# Epoch 946/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.0275e-04
# Epoch 947/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2712e-04
# Epoch 948/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.4354e-04
# Epoch 949/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.5030e-04
# Epoch 950/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9842e-04
# Epoch 951/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 6.7410e-04
# Epoch 952/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.7806e-04
# Epoch 953/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.7525e-04
# Epoch 954/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3714e-04
# Epoch 955/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8991e-04
# Epoch 956/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8531e-04
# Epoch 957/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9406e-04
# Epoch 958/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0763e-04
# Epoch 959/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.4808e-04
# Epoch 960/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.4700e-04
# Epoch 961/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9571e-04
# Epoch 962/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8256e-04
# Epoch 963/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9375e-04
# Epoch 964/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.8953e-04
# Epoch 965/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.0318e-04
# Epoch 966/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8781e-04
# Epoch 967/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3221e-04
# Epoch 968/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9059e-04
# Epoch 969/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9676e-04
# Epoch 970/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.6429e-04
# Epoch 971/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.4264e-04
# Epoch 972/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2956e-04
# Epoch 973/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 8.6428e-04
# Epoch 974/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 6.8494e-04
# Epoch 975/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.3935e-04
# Epoch 976/1000
# 282/282 [==============================] - 0s 67us/sample - loss: 7.0150e-04
# Epoch 977/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 8.0958e-04
# Epoch 978/1000
# 282/282 [==============================] - 0s 57us/sample - loss: 7.2558e-04
# Epoch 979/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9960e-04
# Epoch 980/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.7720e-04
# Epoch 981/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8033e-04
# Epoch 982/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8068e-04
# Epoch 983/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.8846e-04
# Epoch 984/1000
# 282/282 [==============================] - 0s 88us/sample - loss: 6.7064e-04
# Epoch 985/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.7265e-04
# Epoch 986/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.6787e-04
# Epoch 987/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.8935e-04
# Epoch 988/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 6.7371e-04
# Epoch 989/1000
# 282/282 [==============================] - 0s 141us/sample - loss: 6.8996e-04
# Epoch 990/1000
# 282/282 [==============================] - 0s 46us/sample - loss: 7.0463e-04
# Epoch 991/1000
# 282/282 [==============================] - ETA: 0s - loss: 8.0498e-0 - 0s 60us/sample - loss: 6.9481e-04
# Epoch 992/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.0073e-04
# Epoch 993/1000
# 282/282 [==============================] - 0s 71us/sample - loss: 6.8533e-04
# Epoch 994/1000
# 282/282 [==============================] - 0s 74us/sample - loss: 6.6444e-04
# Epoch 995/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9983e-04
# Epoch 996/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.9031e-04
# Epoch 997/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 7.2856e-04
# Epoch 998/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 7.8582e-04
# Epoch 999/1000
# 282/282 [==============================] - 0s 64us/sample - loss: 6.9323e-04
# Epoch 1000/1000
# 282/282 [==============================] - 0s 60us/sample - loss: 6.7454e-04
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri multiple                  96
# _________________________________________________________________
# time_distributed_1 (TimeDist multiple                  0
# _________________________________________________________________
# time_distributed_2 (TimeDist multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  289
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
#
# ==========================
# MAE= [2.0534577]
# RMSE =  2.7408034263302152
# NMSE =  [0.00487824]
# MAPE= [0.00957887]
# IA= [0.9765225]
# U1= 0.006467223383451659
# U2= 0.4871760522350149
# Running time: 20 seconds

# %%
#CNN-LSTM
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import TimeDistributed
from tensorflow.python.keras.layers.convolutional import Conv1D
from tensorflow.python.keras.layers.convolutional import MaxPooling1D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()


# load the dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)


#数据缩放 
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#print(X_scaler)
#print(Y_scaler)
#print(Y)


# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX)
#print(trainY)
#print(testX)
#print(testY)



#重构数据集
##timestep为时间步长
def create_dataset(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep])
    return np.array(dataX), np.array(dataY)



#----------forecasting-----------
timestep = 6
dim = 1
pres=[]
trainX,trainY = create_dataset(train, timestep)
testX,testY = create_dataset(test, timestep) 
print("转为监督学习，训练集数据长度：", len(trainX))
#print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
#print(testX, testY )


# 数据重构为4D [samples, subsequences, timesteps, features]
trainX_input4D = np.reshape(trainX, (trainX.shape[0],1,timestep,dim))
testX_input4D = np.reshape(testX, (testX.shape[0],1,timestep,dim))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input4D.shape,testX_input4D.shape)


# create and fit the convlstm network
if __name__ == '__main__':
    model = Sequential()
    model.add(TimeDistributed(Conv1D(filters=48, kernel_size=1, activation='relu', input_shape=(None,1, testX.shape[1]))))
    model.add(TimeDistributed(MaxPooling1D(pool_size=1)))
    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(48,activation='relu',return_sequences=True))
    model.add(LSTM(12,activation='relu',return_sequences=True))
    model.add(Dense(1))

    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input4D, trainY, epochs=1000)
    


    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input4D)
    testPredict = model.predict(testX_input4D)

    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/cnnoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/cnnEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))

# %%
#GRU
import tensorflow as tf
from tensorflow.python.keras.layers import merge
from tensorflow.python.keras.layers.merge import Multiply
from tensorflow.python.keras.layers.core import *
from tensorflow.python.keras.models import *

import tensorflow.keras.backend as K
from tensorflow.python.keras.layers import Input,Dense,Reshape,Dropout, Embedding, LSTM, Bidirectional,Permute
from tensorflow.python.keras.layers import RepeatVector, TimeDistributed
from tensorflow.python.keras.layers.recurrent import GRU
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam,SGD
import matplotlib.pyplot as plt
import pandas as pd
from pandas import concat, read_csv
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import sklearn.metrics as skm
import math
from math import sqrt
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()

#1. load dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
data = dataset.reshape(-1,6)


timestep = 6
dim = 1

#数据缩放 拆分输入X（6维）&输出Y（1维）
X = dataset[:,0]
X_scaler= (X-np.min(X))/(np.max(X)-np.min(X))
X_scaler = X_scaler.reshape(324,1)
print(X_scaler.shape)

Y = dataset[:,0]
Y_scaler= (Y-np.min(Y))/(np.max(Y)-np.min(Y))
Y_scaler = Y_scaler.reshape(-1)
print(Y_scaler.shape)


#重构数据集
##timestep为时间步长
def create_X(seq, timestep):
    dataX = []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
    return np.array(dataX)

def create_Y(seq, timestep):
    dataY = []
    for i in range(len(seq)-timestep):
        # Y向后移动一位取值
        dataY.append(seq[i+timestep])
    return np.array(dataY)



def get_gru_model():
    K.clear_session() #清除之前的模型，省得压满内存
    inputs = Input(shape=(timestep, dim,))
    gru_units1 = 60
    gru_units2 = 12
    # (batch_size, time_steps, INPUT_DIM) -> (batch_size, input_dim, lstm_units)
    gur_out1 = GRU(gru_units1,return_sequences=True)(inputs)
    gur_out2 = GRU(gru_units2,return_sequences=True)(gur_out1)
    # (batch_size, input_dim, lstm_units) -> (batch_size, input_dim*lstm_units)
    gur_out = Flatten()(gur_out2)
    output = Dense(1, activation='relu')(gur_out)
    model = Model(inputs=inputs, outputs=output)
    return model



#预测
pres=[]
# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
trainX, testX = X_scaler[0:train_size], X_scaler[train_size:len(dataset)]
trainY, testY = Y_scaler[0:train_size], Y_scaler[train_size:len(dataset)]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX,trainX.shape)
#print(trainY,trainY.shape)
#print(testX,testX.shape)
#print(testY,testY.shape)

train_X=create_X(trainX,timestep)#(246,6)
#print(train_X,train_X.shape)
train_Y=create_Y(trainY,timestep)#(246,)
#print(train_Y,train_Y.shape)
test_X=create_X(testX,timestep)#(66,6,6)
#print(test_X,test_X.shape)
test_Y=create_Y(testY,timestep)#(66,)
#print(test_Y,test_Y.shape)

if __name__ == '__main__':
    np.random.seed(6)
        
    model = get_gru_model()
    optimizer = Adam(0.01)
    model.compile(optimizer=optimizer, loss='mse')
    print(model.summary())
    
    model.fit(train_X, train_Y, epochs=1000, batch_size=64)

    # 开始预测
    trainPredict = model.predict(train_X)
    testPredict = model.predict(test_X)
    
    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/gruoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/gruEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))

# %%
#LSTM
import tensorflow as tf
from tensorflow.python.keras.layers import merge
from tensorflow.python.keras.layers.merge import Multiply
from tensorflow.python.keras.layers.core import *
from tensorflow.python.keras.models import *

import tensorflow.keras.backend as K
from tensorflow.python.keras.layers import Input,Dense,Reshape,Dropout, Embedding, LSTM, Bidirectional,Permute
from tensorflow.python.keras.layers import RepeatVector, TimeDistributed
from tensorflow.python.keras.layers.recurrent import GRU
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam,SGD
import matplotlib.pyplot as plt
import pandas as pd
from pandas import concat, read_csv
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import sklearn.metrics as skm
import math
from math import sqrt
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()

#1. load dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
data = dataset.reshape(-1,6)


timestep = 6
dim = 1

#数据缩放 拆分输入X（7维）&输出Y（1维）
X = dataset[:,0]
X_scaler= (X-np.min(X))/(np.max(X)-np.min(X))
X_scaler = X_scaler.reshape(324,1)
print(X_scaler.shape)

Y = dataset[:,0]
Y_scaler= (Y-np.min(Y))/(np.max(Y)-np.min(Y))
Y_scaler = Y_scaler.reshape(-1)
print(Y_scaler.shape)


#重构数据集
##timestep为时间步长
def create_X(seq, timestep):
    dataX = []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
    return np.array(dataX)

def create_Y(seq, timestep):
    dataY = []
    for i in range(len(seq)-timestep):
        # Y向后移动一位取值
        dataY.append(seq[i+timestep])
    return np.array(dataY)



def get_lstm_model():
    K.clear_session() #清除之前的模型，省得压满内存
    inputs = Input(shape=(timestep, dim,))
    lstm_units1 = 12
    lstm_units2 = 12
    lstm_out1 = LSTM(lstm_units1, return_sequences=True)(inputs)
    lstm_out2 = LSTM(lstm_units2, return_sequences=True)(lstm_out1)
    dropout_out = Dropout(0.5)(lstm_out2)
    lstm_out = Flatten()(dropout_out)
    output = Dense(1, activation='relu')(lstm_out)
    model = Model(inputs=inputs, outputs=output)
    return model



#预测
pres=[]
# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
trainX, testX = X_scaler[0:train_size], X_scaler[train_size:len(dataset)]
trainY, testY = Y_scaler[0:train_size], Y_scaler[train_size:len(dataset)]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX,trainX.shape)
#print(trainY,trainY.shape)
#print(testX,testX.shape)
#print(testY,testY.shape)

train_X=create_X(trainX,timestep)#(246,6)
#print(train_X,train_X.shape)
train_Y=create_Y(trainY,timestep)#(246,)
#print(train_Y,train_Y.shape)
test_X=create_X(testX,timestep)#(66,6,6)
#print(test_X,test_X.shape)
test_Y=create_Y(testY,timestep)#(66,)
#print(test_Y,test_Y.shape)

if __name__ == '__main__':
    np.random.seed(6)
        
    model = get_lstm_model()
    optimizer = Adam(0.01)
    model.compile(optimizer=optimizer, loss='mse')
    print(model.summary())
    
    model.fit(train_X, train_Y, epochs=1000, batch_size=64)

    trainPredict = model.predict(train_X)
    testPredict = model.predict(test_X)
    
    
    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/lstmoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/lstmEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))

# %%
#Bi-LSTM
import tensorflow as tf
from tensorflow.python.keras.layers import merge
from tensorflow.python.keras.layers.merge import Multiply
from tensorflow.python.keras.layers.core import *
from tensorflow.python.keras.models import *

import tensorflow.keras.backend as K
from tensorflow.python.keras.layers import Input,Dense,Reshape,Dropout, Embedding, LSTM, Bidirectional,Permute
from tensorflow.python.keras.layers import RepeatVector, TimeDistributed
from tensorflow.python.keras.layers.recurrent import GRU
from tensorflow.python.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam,SGD
import matplotlib.pyplot as plt
import pandas as pd
from pandas import concat, read_csv
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import sklearn.metrics as skm
import math
from math import sqrt
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()

#1. load dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
data = dataset.reshape(-1,6)


timestep = 6
dim = 1

#数据缩放 拆分输入X（7维）&输出Y（1维）
X = dataset[:,0]
X_scaler= (X-np.min(X))/(np.max(X)-np.min(X))
X_scaler = X_scaler.reshape(324,1)
print(X_scaler.shape)

Y = dataset[:,0]
Y_scaler= (Y-np.min(Y))/(np.max(Y)-np.min(Y))
Y_scaler = Y_scaler.reshape(-1)
print(Y_scaler.shape)


#重构数据集
##timestep为时间步长
def create_X(seq, timestep):
    dataX = []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
    return np.array(dataX)

def create_Y(seq, timestep):
    dataY = []
    for i in range(len(seq)-timestep):
        # Y向后移动一位取值
        dataY.append(seq[i+timestep])
    return np.array(dataY)



def get_bilstm_model():
    K.clear_session() #清除之前的模型，省得压满内存
    inputs = Input(shape=(timestep, dim,))
    lstm_units1 = 60
    lstm_units2 = 12
    bilstm_out1 = Bidirectional(LSTM(lstm_units1,return_sequences=True),merge_mode='concat')(inputs)
    bilstm_out2 = LSTM(lstm_units2, return_sequences=True)(bilstm_out1)
    dropout_out = Dropout(0.5)(bilstm_out2)
    bilstm_out = Flatten()(dropout_out)
    output = Dense(1, activation='relu')(bilstm_out)
    model = Model(inputs=inputs, outputs=output)
    return model



#预测
pres=[]
# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
trainX, testX = X_scaler[0:train_size], X_scaler[train_size:len(dataset)]
trainY, testY = Y_scaler[0:train_size], Y_scaler[train_size:len(dataset)]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)
#print(trainX,trainX.shape)
#print(trainY,trainY.shape)
#print(testX,testX.shape)
#print(testY,testY.shape)

train_X=create_X(trainX,timestep)#(246,6)
#print(train_X,train_X.shape)
train_Y=create_Y(trainY,timestep)#(246,)
#print(train_Y,train_Y.shape)
test_X=create_X(testX,timestep)#(66,6,6)
#print(test_X,test_X.shape)
test_Y=create_Y(testY,timestep)#(66,)
#print(test_Y,test_Y.shape)

if __name__ == '__main__':
    np.random.seed(6)
        
    model = get_bilstm_model()
    optimizer = Adam(0.01)
    model.compile(optimizer=optimizer, loss='mse')
    print(model.summary())
    
    model.fit(train_X, train_Y, epochs=1000, batch_size=64)

    trainPredict = model.predict(train_X)
    testPredict = model.predict(test_X)
    
    # 逆缩放预测值
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    testPre = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    testPre = testPre.reshape(-1)

    Y = dataset[train_size+timestep:len(dataset)]
    testY_ori = Y.reshape((-1,1))
 


    #计算误差
    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre[i])
        error1.append(abs((testY_ori[i] - testPre[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre[i]*testPre[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=np.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre[i])/testY_ori[i])*((testY_ori[i+1] - testPre[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre=testPre.reshape(-1)
    testPre=pd.DataFrame(testPre)
    testPre.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/lstmoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/lstmEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)

    plt.figure(facecolor='white')
    plt.plot(testPre,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre)



end = time.time()
print('Running time: %d seconds'%(end - start))

# %%
# SVR
import numpy as np  # numpy库
from sklearn.linear_model import BayesianRidge, LinearRegression, ElasticNet  # 批量导入要实现的回归算法
from sklearn.svm import SVR  # SVM中的回归算法
#from sklearn.ensemble.gradient_boosting import GradientBoostingRegressor  # 集成算法
from sklearn.model_selection import cross_val_score  # 交叉检验
from sklearn.metrics import explained_variance_score, mean_absolute_error, mean_squared_error, r2_score  # 批量导入指标算法
import pandas as pd  # 导入pandas
import matplotlib.pyplot as plt  # 导入图形展示库

from pandas import concat, read_csv
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import sklearn.metrics as skm
import math
from math import sqrt
import time

# fix random seed for reproducibility
np.random.seed(7)

start = time.time()

#1. load dataset
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
data = dataset.reshape(-1,6)


timestep = 6
dim = 1

#数据缩放 
X = dataset[:,0]
X_scaler= (X-np.min(X))/(np.max(X)-np.min(X))
#X_scaler = X_scaler.reshape(324,1)
print(X_scaler.shape)

Y = dataset[:,0]
Y_scaler= (Y-np.min(Y))/(np.max(Y)-np.min(Y))
#Y_scaler = Y_scaler.reshape(-1)
print(Y_scaler.shape)

#重构数据集
##timestep为时间步长
def create_X(seq, timestep):
    dataX = []
    for i in range(len(seq)-timestep):
        a = seq[i:(i+timestep)]
        # X按照顺序取值 每次在后面增加一个数据
        dataX.append(a)
    return np.array(dataX)

def create_Y(seq, timestep):
    dataY = []
    for i in range(len(seq)-timestep):
        # Y向后移动一位取值
        dataY.append(seq[i+timestep])
    return np.array(dataY)

# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
trainX, testX = X_scaler[0:train_size], X_scaler[train_size:len(dataset)]
trainY, testY = Y_scaler[0:train_size], Y_scaler[train_size:len(dataset)]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)

train_X=create_X(trainX,timestep)#(246,6)
#print(train_X,train_X.shape)
train_Y=create_Y(trainY,timestep)#(246,)
#print(train_Y,train_Y.shape)
test_X=create_X(testX,timestep)#(66,6,6)
#print(test_X,test_X.shape)
test_Y=create_Y(testY,timestep)#(66,)
#print(test_Y,test_Y.shape)

# 训练回归模型
n_folds = 6  # 设置交叉检验的次数
model_br = BayesianRidge()  # 建立贝叶斯岭回归模型对象
#model_lr = LinearRegression()  # 建立普通线性回归模型对象
#model_etc = ElasticNet()  # 建立弹性网络回归模型对象
model_svr = SVR(kernel='rbf',C=100, gamma=0.1)
#model_gbr = GradientBoostingRegressor()  # 建立梯度增强回归模型对象
model_names = ['BayesianRidge', 'LinearRegression', 'ElasticNet', 'SVR', 'GBR']  # 不同模型的名称列表
model_dic = [model_br, model_svr]  # 不同回归模型对象的集合

cv_score_list = []  # 交叉检验结果列表

pre_y_list = []  # 各个回归模型预测的y值列表
for model in model_dic:  # 读出每个回归模型对象
    scores = cross_val_score(model, train_X, train_Y, cv=n_folds)  # 将每个回归模型导入交叉检验模型中做训练检验
    cv_score_list.append(scores)  # 将交叉检验结果存入结果列表
    pre_y_list.append(model.fit(train_X, train_Y).predict(train_X))  # 将回归训练中得到的预测y存入列表

# 模型应用
testPredict = model_svr.predict(test_X)  
#print (testPredict)
#print (testY_ori)


# 逆缩放预测值
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv',usecols=[0], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
Y = dataset[train_size+timestep:len(dataset)]
testY_ori = Y.reshape((-1,1))
testPredict = testPredict*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
testPredict = testPredict.reshape(-1)

    
#误差计算
error = []#Y-Y'
error1= []#abs((Y-Y')/Y)
error2= []#Y*Y'
squared1 =[]#Y*Y
squared2 =[]#Y'*Y'
for i in range(len(testY_ori)):
    error.append(testY_ori[i] - testPredict[i])
    error1.append(abs((testY_ori[i] - testPredict[i])/testY_ori[i]))
    error2.append(testY_ori[i]*testPredict[i])
    squared1.append(testY_ori[i]*testY_ori[i])
    squared2.append(testPredict[i]*testPredict[i])
        
        
squaredError = []#(Y-Y')^2
absError = []#abs(Y-Y')
for val in error:    
    squaredError.append(val * val)#target-prediction之差平方     
    absError.append(abs(val))#误差绝对值
        
MSE=sum(squaredError) / len(squaredError)
meannn=np.mean(testY_ori)
NMSEerror = []
IAerror = []
for i in range(len(testY_ori)):
    NMSEerror.append(squaredError[i]/error2[i])
    IAerror.append((abs(testY_ori[i] - meannn)+abs(testPredict[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPredict[i] - meannn)))
    
U2error1 = []
U2error2 = []
for i in range(len(testY_ori)-1):
    U2error1.append(((testY_ori[i+1] - testPredict[i+1])/testY_ori[i])*((testY_ori[i+1] - testPredict[i+1])/testY_ori[i]))
    U2error2.append(((testY_ori[i+1] - testPredict[i])/testY_ori[i])*((testY_ori[i+1] - testPredict[i])/testY_ori[i]))
print('\n==========================')
MAE=sum(absError)/len(absError)
print('MAE=',MAE)
from math import sqrt
RMSE=sqrt(MSE)
print("RMSE = ", RMSE)#均方根误差RMSE
NMSE=sum(NMSEerror)
print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
MAPE=sum(error1)/len(error1)
print('MAPE=',MAPE)
IA=1-sum(squaredError)/sum(IAerror)
print('IA=',IA)#一致性指数
U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
print('U1=',U1index)
U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
print('U2=',U2index)

testPredict=pd.DataFrame(testPredict)
testPredict.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/svroutput.csv', header=False)
import csv
Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/svrEvaluation.csv", "a", newline='', encoding='utf-8') as file:
    writer = csv.writer(file ,delimiter=',')
    writer.writerow(Evaluation_index)

plt.figure(facecolor='white')
plt.plot(testPredict,color='green', label='Predict')
plt.plot(testY_ori,color='pink', label='Original')
plt.legend(loc='best')
plt.show()
# Out:
# (324,)
# (324,)
# 原始训练集的长度： 252
# 原始测试集的长度： 72
#
# ==========================
# MAE= [9.1965685]
# RMSE =  10.361772308751913
# NMSE =  [0.16202043]
# MAPE= [0.04316568]
# IA= [0.67043066]
# U1= 0.025215661254674993
# U2= 0.8930231116919894
