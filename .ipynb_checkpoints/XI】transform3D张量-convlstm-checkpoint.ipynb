# %%
#convlstm多变量多步 加入SED
import numpy
import pandas
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.python.keras.layers import ConvLSTM2D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time
# fix random seed for reproducibility
numpy.random.seed(7)

start = time.time()

# load the dataset
#dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-IMF1.csv', usecols=[6], engine='python')
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-TVFEMD-BDX.csv', engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)
X14 = dataset[:,0]
X14_scaler= (X14-numpy.min(X14))/(numpy.max(X14)-numpy.min(X14))
X14_scaler = X14_scaler.reshape(-1)
X23 = dataset[:,6]#Y
X23_scaler= (X23-numpy.min(X23))/(numpy.max(X23)-numpy.min(X23))
X23_scaler = X23_scaler.reshape(-1)
X24 = dataset[:,1]
X24_scaler= (X24-numpy.min(X24))/(numpy.max(X24)-numpy.min(X24))
X24_scaler = X24_scaler.reshape(-1)
X31 = dataset[:,2]
X31_scaler= (X31-numpy.min(X31))/(numpy.max(X31)-numpy.min(X31))
X31_scaler = X31_scaler.reshape(-1)
X42 = dataset[:,4]
X42_scaler= (X42-numpy.min(X42))/(numpy.max(X42)-numpy.min(X42))
X42_scaler = X42_scaler.reshape(-1)
X44 = dataset[:,3]
X44_scaler= (X44-numpy.min(X44))/(numpy.max(X44)-numpy.min(X44))
X44_scaler = X44_scaler.reshape(-1)
X46 = dataset[:,5]
X46_scaler= (X46-numpy.min(X46))/(numpy.max(X46)-numpy.min(X46))
X46_scaler = X46_scaler.reshape(-1)
#print(X14_scaler,X23_scaler,X24_scaler,X31_scaler,X42_scaler,X44_scaler,X46_scaler)

XX = numpy.zeros([324,4,6])
XX[:,0,3] = X14_scaler
XX[:,1,2] = X23_scaler
XX[:,1,3] = X24_scaler
XX[:,2,0] = X31_scaler
XX[:,3,1] = X42_scaler
XX[:,3,3] = X44_scaler
XX[:,3,5] = X46_scaler

# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
train, test = XX[0:train_size,:,:], XX[train_size:len(dataset),:,:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)


# 切片
def create_train(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep,:,:])
    return numpy.array(dataX), numpy.array(dataY)

def create_testX(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
    return numpy.array(dataX)
# fix random seed for reproducibility
numpy.random.seed(7)



#----------forecasting-----------
timestep = 6
pres=[]
trainX,trainY = create_train(train, timestep)
testX = create_testX(test, timestep) 
testY = test[timestep:len(testY),1,2]
print("转为监督学习，训练集数据长度：", len(trainX))
print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
print(testX, testY )


# 数据重构为5D [samples, timesteps, rows, columns, features]
trainX_input5D = numpy.reshape(trainX, (trainX.shape[0], timestep,4,6, 1))
testX_input5D = numpy.reshape(testX, (testX.shape[0],timestep, 4,6, 1))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input5D.shape,testX_input5D.shape)


# create and fit the convlstm network
from tensorflow.python.keras.layers.convolutional import Conv3D ,Conv2D
if __name__ == '__main__':
    model = Sequential()
    model.add(ConvLSTM2D(filters=64, kernel_size=(3, 3), activation='relu', input_shape=(timestep, 4,6,1),
                         padding='same',return_sequences=True))
    model.add(ConvLSTM2D(filters=64, kernel_size=(3, 3),activation='relu',
                         padding='same',return_sequences=False))
    model.add(Conv2D(filters=1, kernel_size=(3, 3),
               activation='sigmoid',
               padding='same', data_format='channels_last'))
#    model.add(Flatten())
#    model.add(Dense(1))
    
    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input5D, trainY, epochs=50)

    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input5D)
    testPredict = model.predict(testX_input5D)

    # 逆缩放预测值
    #dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-IMF1.csv', engine='python')
    #dataset = dataframe.values
    #dataset = dataset.astype('float32')
    #Y = dataset[:,6]
    #trainPredict = trainPredict*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    #trainY_re = trainY*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    #trainY_re=trainY_re.reshape((246,1))
    testPredict = testPredict*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    #testY_re = testY*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    testY_ori=X23[train_size+timestep:len(dataset)]
    testY_ori=testY_ori.reshape((66,1))

    # 计算误差
    #trainScore = math.sqrt(mean_squared_error(trainY_re[:,0], trainPredict[:,0]))
    #print('Train Score: %.2f RMSE' % (trainScore))
    #testScore = math.sqrt(mean_squared_error(testY_re[:,0], testPredict[:,0]))
    #print('Test Score: %.2f RMSE' % (testScore))


    error = []
    error1= []
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPredict[i])
        error1.append(abs((testY_ori[i] - testPredict[i])/testY_ori[i]))
    squaredError = []
    absError = []
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
    MSE=sum(squaredError) / len(squaredError)
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE

    plt.figure(facecolor='white')
    plt.plot(testPredict,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPredict)

# %%
#convlstm多变量多步 加入SED
import numpy
import pandas
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.python.keras.layers import ConvLSTM2D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time
# fix random seed for reproducibility
numpy.random.seed(7)

start = time.time()

# load the dataset
#dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-IMF1.csv', usecols=[6], engine='python')
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD-TVFEMD-BDX.csv', engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)
X11 = dataset[:,0]#Y
X11_scaler= (X11-numpy.min(X11))/(numpy.max(X11)-numpy.min(X11))
X11_scaler = X11_scaler.reshape(-1)

X12 = dataset[:,1]
X12_scaler= (X12-numpy.min(X12))/(numpy.max(X12)-numpy.min(X12))
X12_scaler = X12_scaler.reshape(-1)

X13 = dataset[:,2]
X13_scaler= (X13-numpy.min(X13))/(numpy.max(X13)-numpy.min(X13))
X13_scaler = X13_scaler.reshape(-1)

X21 = dataset[:,3]
X21_scaler= (X21-numpy.min(X21))/(numpy.max(X21)-numpy.min(X21))
X21_scaler = X21_scaler.reshape(-1)

X22 = dataset[:,4]
X22_scaler= (X22-numpy.min(X22))/(numpy.max(X22)-numpy.min(X22))
X22_scaler = X22_scaler.reshape(-1)

X23 = dataset[:,5]
X23_scaler= (X23-numpy.min(X23))/(numpy.max(X23)-numpy.min(X23))
X23_scaler = X23_scaler.reshape(-1)



XX = numpy.zeros([324,2,3])
XX[:,0,0] = X11_scaler
XX[:,0,1] = X12_scaler
XX[:,0,2] = X13_scaler
XX[:,1,0] = X21_scaler
XX[:,1,1] = X22_scaler
XX[:,1,2] = X23_scaler

# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
train, test = XX[0:train_size,:,:], XX[train_size:len(dataset),:,:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)


# 切片
def create_train(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep,:,:])
    return numpy.array(dataX), numpy.array(dataY)

def create_testX(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
    return numpy.array(dataX)
# fix random seed for reproducibility
numpy.random.seed(7)



#----------forecasting-----------
timestep = 6
pres=[]
trainX,trainY = create_train(train, timestep)
testX = create_testX(test, timestep) 
testY = test[timestep:len(X11),0,0]
print("转为监督学习，训练集数据长度：", len(trainX))
#print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
#print(testX, testY )


# 数据重构为5D [samples, timesteps, rows, columns, features]
trainX_input5D = numpy.reshape(trainX, (trainX.shape[0], timestep,2,3, 1))
testX_input5D = numpy.reshape(testX, (testX.shape[0],timestep, 2,3, 1))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input5D.shape,testX_input5D.shape)


# create and fit the convlstm network
from tensorflow.python.keras.layers.convolutional import Conv3D ,Conv2D
if __name__ == '__main__':
    model = Sequential()
    model.add(ConvLSTM2D(filters=72, kernel_size=(1, 2), activation='relu', input_shape=(timestep, 2,3,1),
                         padding='same',return_sequences=True))
    model.add(ConvLSTM2D(filters=12, kernel_size=(1, 2),activation='relu',
                         padding='same',return_sequences=False))
    model.add(Conv2D(filters=1, kernel_size=(1, 1),
               activation='sigmoid',
               padding='same', data_format='channels_last'))
#    model.add(Flatten())
#    model.add(Dense(1))
    
    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input5D, trainY, epochs=700)

    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input5D)
    testPredict = model.predict(testX_input5D)
    
    # 逆缩放预测值
    testPre1 = testPredict[:,0,0,:]
    testPre1 = testPre1.reshape(-1)
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD-TVFEMD-BDX.csv', engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    Y = dataset[:,0]#Y
    testBDX_re = testPre1*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    testBDX_re = testBDX_re.reshape(-1)
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/QSX.csv', usecols=[0], engine='python')
    QSX = dataframe.values
    QSX = QSX.astype('float32')
    QSX = QSX[train_size+timestep:len(dataset)]
    QSX = QSX.reshape(-1)
    testPre_re=QSX + testBDX_re
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    Y = dataset[:,0]
    Y = Y[train_size+timestep:len(dataset)]
    #testY_ori = testY*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    #testY_ori = testY_ori.reshape((-1,1))
    testY_ori = Y.reshape((-1,1))

    # 计算误差
    #trainScore = math.sqrt(mean_squared_error(trainY_re[:,0], trainPredict[:,0]))
    #print('Train Score: %.2f RMSE' % (trainScore))
    #testScore = math.sqrt(mean_squared_error(testY_re[:,0], testPredict[:,0]))
    #print('Test Score: %.2f RMSE' % (testScore))


    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre_re[i])
        error1.append(abs((testY_ori[i] - testPre_re[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre_re[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre_re[i]*testPre_re[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=numpy.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre_re[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre_re[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre_re[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre_re[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre_re[i])/testY_ori[i])*((testY_ori[i+1] - testPre_re[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre_re=testPre_re.reshape(-1)
    testPre_re=pandas.DataFrame(testPre_re)
    testPre_re.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)
    
    plt.figure(facecolor='white')
    plt.plot(testPre_re,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre_re)



end = time.time()
print('Running time: %d seconds'%(end - start))
# Out:
# 数据集的长度： 324
# 原始训练集的长度： 252
# 原始测试集的长度： 72
# 转为监督学习，训练集数据长度： 246
# 转为监督学习，测试集数据长度： 66
# 构造得到模型的输入数据(训练数据已有标签trainY):  (246, 6, 2, 3, 1) (66, 6, 2, 3, 1)
# Train on 246 samples
# Epoch 1/700
# 246/246 [==============================] - 7s 30ms/sample - loss: 0.0497
# Epoch 2/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0459
# Epoch 3/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0412
# Epoch 4/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0387
# Epoch 5/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0369
# Epoch 6/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0353
# Epoch 7/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0340
# Epoch 8/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0324
# Epoch 9/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0315
# Epoch 10/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0305
# Epoch 11/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0295
# Epoch 12/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0286
# Epoch 13/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0276
# Epoch 14/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0268
# Epoch 15/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0259
# Epoch 16/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0253
# Epoch 17/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0250
# Epoch 18/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0237
# Epoch 19/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0228
# Epoch 20/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0226
# Epoch 21/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0222
# Epoch 22/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0209
# Epoch 23/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0198
# Epoch 24/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0191
# Epoch 25/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0195
# Epoch 26/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0196
# Epoch 27/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0182
# Epoch 28/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0170
# Epoch 29/700
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0162
# Epoch 30/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0160
# Epoch 31/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0160
# Epoch 32/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0153
# Epoch 33/700
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0148
# Epoch 34/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0140
# Epoch 35/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0130
# Epoch 36/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0125
# Epoch 37/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0117
# Epoch 38/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0115
# Epoch 39/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0110
# Epoch 40/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0097
# Epoch 41/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0092
# Epoch 42/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0096
# Epoch 43/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0097
# Epoch 44/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0097
# Epoch 45/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0086
# Epoch 46/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0075
# Epoch 47/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.
700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 600/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 601/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0019
# Epoch 602/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 603/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 604/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 605/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 606/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 607/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 608/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 609/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 610/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 611/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 612/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0019
# Epoch 613/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0019
# Epoch 614/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0021
# Epoch 615/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0020
# Epoch 616/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 617/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 618/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 619/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 620/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 621/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 622/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 623/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 624/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 625/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 626/700
# 246/246 [==============================] - 0s 1000us/sample - loss: 0.0016
# Epoch 627/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 628/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 629/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 630/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 631/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 632/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 633/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 634/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 635/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 636/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 637/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 638/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 639/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 640/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 641/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 642/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 643/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 644/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 645/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 646/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 647/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 648/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 649/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 650/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 651/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 652/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 653/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 654/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 655/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 656/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 657/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 658/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 659/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 660/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 661/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 662/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 663/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 664/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 665/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 666/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 667/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 668/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 669/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 670/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 671/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 672/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 673/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 674/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 675/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 676/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 677/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 678/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 679/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 680/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 681/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 682/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 683/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 684/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 685/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 686/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 687/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 688/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 689/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 690/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0014
# Epoch 691/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0016
# Epoch 692/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 693/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0015
# Epoch 694/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 695/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 696/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 697/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0018
# Epoch 698/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0021
# Epoch 699/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Epoch 700/700
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0017
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_34 (ConvLSTM2D) (None, 6, 2, 3, 72)       42336
# _________________________________________________________________
# conv_lst_m2d_35 (ConvLSTM2D) (None, 2, 3, 12)          8112
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 2, 3, 1)           13
# =================================================================
# Total params: 50,461
# Trainable params: 50,461
# Non-trainable params: 0
# _________________________________________________________________
#
# ==========================
# MAE= [2.957333]
# RMSE =  3.8449453340570665
# NMSE =  [0.02243077]
# MAPE= [0.01415033]
# IA= [0.9467408]
# U1= 0.009150739590980355
# U2= 0.620789037045361
# Running time: 204 seconds

# %%
#convlstm多变量多步 加入SED
import numpy
import pandas
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.python.keras.layers import ConvLSTM2D
from tensorflow.python.keras.layers import Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
#matplotlib inline
import time
# fix random seed for reproducibility
numpy.random.seed(7)

start = time.time()

# load the dataset
#dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/PD-IMF1.csv', usecols=[6], engine='python')
dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD-TVFEMD-BDX.csv', engine='python')
#print(dataframe)
print("数据集的长度：",len(dataframe))
dataset = dataframe.values
# 将整型变为float
dataset = dataset.astype('float32')
#print(dataset)
X1 = dataset[:,1]#Y
X1_scaler= (X1-numpy.min(X1))/(numpy.max(X1)-numpy.min(X1))
X1_scaler = X1_scaler.reshape(-1)

X2 = dataset[:,2]
X2_scaler= (X2-numpy.min(X2))/(numpy.max(X2)-numpy.min(X2))
X2_scaler = X2_scaler.reshape(-1)

X3 = dataset[:,3]
X3_scaler= (X3-numpy.min(X3))/(numpy.max(X3)-numpy.min(X3))
X3_scaler = X3_scaler.reshape(-1)

X4 = dataset[:,4]
X4_scaler= (X4-numpy.min(X4))/(numpy.max(X4)-numpy.min(X4))
X4_scaler = X4_scaler.reshape(-1)

X5 = dataset[:,5]
X5_scaler= (X5-numpy.min(X5))/(numpy.max(X5)-numpy.min(X5))
X5_scaler = X5_scaler.reshape(-1)

Y = dataset[:,0]
Y_scaler= (Y-numpy.min(Y))/(numpy.max(Y)-numpy.min(Y))
Y_scaler = Y_scaler.reshape(-1)



XX = numpy.zeros([324,3,3])
XX[:,0,0] = X1_scaler
XX[:,0,1] = Y_scaler
XX[:,0,2] = X2_scaler
XX[:,1,0] = Y_scaler
XX[:,1,1] = X3_scaler
XX[:,1,2] = Y_scaler
XX[:,2,0] = X4_scaler
XX[:,2,1] = Y_scaler
XX[:,2,2] = X5_scaler

# 将数据拆分成训练和测试，7/9作为训练数据
train_size = int(len(dataset) * 0.78)
test_size = len(dataset) - train_size
train, test = XX[0:train_size,:,:], XX[train_size:len(dataset),:,:]
print("原始训练集的长度：",train_size)
print("原始测试集的长度：",test_size)


# 切片
def create_train(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
        # Y向后移动一位取值
        dataY.append(seq[i + timestep,:,:])
    return numpy.array(dataX), numpy.array(dataY)

def create_testX(seq, timestep):
    dataX, dataY = [], []
    for i in range(len(seq)-timestep):
        a = seq[i:(i + timestep),:,:]
        # X按照顺序取值
        dataX.append(a)
    return numpy.array(dataX)
# fix random seed for reproducibility
numpy.random.seed(7)



#----------forecasting-----------
timestep = 6
pres=[]
trainX,trainY = create_train(train, timestep)
testX = create_testX(test, timestep) 
testY = test[timestep:len(X11),0,0]
print("转为监督学习，训练集数据长度：", len(trainX))
#print(trainX,trainY)
print("转为监督学习，测试集数据长度：",len(testX))
#print(testX, testY )


# 数据重构为5D [samples, timesteps, rows, columns, features]
trainX_input5D = numpy.reshape(trainX, (trainX.shape[0], timestep,3,3, 1))
testX_input5D = numpy.reshape(testX, (testX.shape[0],timestep, 3,3, 1))
print('构造得到模型的输入数据(训练数据已有标签trainY): ',trainX_input5D.shape,testX_input5D.shape)


# create and fit the convlstm network
from tensorflow.python.keras.layers.convolutional import Conv3D ,Conv2D
if __name__ == '__main__':
    model = Sequential()
    model.add(ConvLSTM2D(filters=60, kernel_size=(2, 2), activation='relu', input_shape=(timestep, 3,3,1),
                         padding='same',return_sequences=True))
    model.add(ConvLSTM2D(filters=12, kernel_size=(2, 2),activation='relu',
                         padding='same',return_sequences=False))
    model.add(Conv2D(filters=1, kernel_size=(1, 1),
               activation='sigmoid',
               padding='same', data_format='channels_last'))
#    model.add(Flatten())
#    model.add(Dense(1))
    
    model.compile(loss='mse', optimizer='adam')
    model.fit(trainX_input5D, trainY, epochs=1000)

    # 打印模型
    model.summary()

    # 开始预测
    trainPredict = model.predict(trainX_input5D)
    testPredict = model.predict(testX_input5D)
    
    # 逆缩放预测值
    testPre1 = testPredict[:,1,0,:]
    testPre1 = testPre1.reshape(-1)
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD-TVFEMD-BDX.csv', engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    Y = dataset[:,0]#Y
    testBDX_re = testPre1*((numpy.max(Y)-numpy.min(Y)))+numpy.min(Y)
    testBDX_re = testBDX_re.reshape(-1)
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/QSX.csv', usecols=[0], engine='python')
    QSX = dataframe.values
    QSX = QSX.astype('float32')
    QSX = QSX[train_size+timestep:len(dataset)]
    QSX = QSX.reshape(-1)
    testPre_re=QSX + testBDX_re
    dataframe = read_csv('C:/Users/Administrator/Desktop/XI-2/data/try2ed/PD.csv', engine='python')
    dataset = dataframe.values
    dataset = dataset.astype('float32')
    Y = dataset[:,0]
    Y = Y[train_size+timestep:len(dataset)]
    #testY_ori = testY*((np.max(dataset)-np.min(dataset)))+np.min(dataset)
    #testY_ori = testY_ori.reshape((-1,1))
    testY_ori = Y.reshape((-1,1))

    # 计算误差
    #trainScore = math.sqrt(mean_squared_error(trainY_re[:,0], trainPredict[:,0]))
    #print('Train Score: %.2f RMSE' % (trainScore))
    #testScore = math.sqrt(mean_squared_error(testY_re[:,0], testPredict[:,0]))
    #print('Test Score: %.2f RMSE' % (testScore))


    error = []#Y-Y'
    error1= []#abs((Y-Y')/Y)
    error2= []#Y*Y'
    squared1 =[]#Y*Y
    squared2 =[]#Y'*Y'
    for i in range(len(testY_ori)):
        error.append(testY_ori[i] - testPre_re[i])
        error1.append(abs((testY_ori[i] - testPre_re[i])/testY_ori[i]))
        error2.append(testY_ori[i]*testPre_re[i])
        squared1.append(testY_ori[i]*testY_ori[i])
        squared2.append(testPre_re[i]*testPre_re[i])
        
        
    squaredError = []#(Y-Y')^2
    absError = []#abs(Y-Y')
    for val in error:    
        squaredError.append(val * val)#target-prediction之差平方     
        absError.append(abs(val))#误差绝对值
        
    MSE=sum(squaredError) / len(squaredError)
    meannn=numpy.mean(testY_ori)
    NMSEerror = []
    IAerror = []
    for i in range(len(testY_ori)):
        NMSEerror.append(squaredError[i]/error2[i])
        IAerror.append((abs(testY_ori[i] - meannn)+abs(testPre_re[i] - meannn))*(abs(testY_ori[i] - meannn)+abs(testPre_re[i] - meannn)))
    
    U2error1 = []
    U2error2 = []
    for i in range(len(testY_ori)-1):
        U2error1.append(((testY_ori[i+1] - testPre_re[i+1])/testY_ori[i])*((testY_ori[i+1] - testPre_re[i+1])/testY_ori[i]))
        U2error2.append(((testY_ori[i+1] - testPre_re[i])/testY_ori[i])*((testY_ori[i+1] - testPre_re[i])/testY_ori[i]))
    print('\n==========================')
    MAE=sum(absError)/len(absError)
    print('MAE=',MAE)
    from math import sqrt
    RMSE=sqrt(MSE)
    print("RMSE = ", RMSE)#均方根误差RMSE
    NMSE=sum(NMSEerror)
    print("NMSE = ", NMSE)#误差平方的归一化平均值NMSE
    MAPE=sum(error1)/len(error1)
    print('MAPE=',MAPE)
    IA=1-sum(squaredError)/sum(IAerror)
    print('IA=',IA)#一致性指数
    U1index=RMSE/(sqrt(sum(squared1)/len(squared1))+sqrt(sum(squared2)/len(squared2)))
    print('U1=',U1index)
    U2index=(sqrt(sum(U2error1)/len(testY_ori)))/(sqrt(sum(U2error2)/len(testY_ori)))
    print('U2=',U2index)

    #print(testPredict)
    testPre_re=testPre_re.reshape(-1)
    testPre_re=pandas.DataFrame(testPre_re)
    testPre_re.to_csv('C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmoutput.csv', header=False)
    import csv
    Evaluation_index = [MAE,RMSE,NMSE,MAPE,IA,U1index,U2index]
    with open("C:/Users/Administrator/Desktop/XI-2/data/pre_result/convlstmEvaluation.csv", "a", newline='', encoding='utf-8') as file:
        writer = csv.writer(file ,delimiter=',')
        writer.writerow(Evaluation_index)
    
    plt.figure(facecolor='white')
    plt.plot(testPre_re,color='green', label='Predict')
    plt.plot(testY_ori,color='pink', label='Original')
    plt.legend(loc='best')
    plt.show()
    pres.append(testPre_re)



end = time.time()
print('Running time: %d seconds'%(end - start))
# Out:
# 数据集的长度： 324
# 原始训练集的长度： 252
# 原始测试集的长度： 72
# 转为监督学习，训练集数据长度： 246
# 转为监督学习，测试集数据长度： 66
# 构造得到模型的输入数据(训练数据已有标签trainY):  (246, 6, 3, 3, 1) (66, 6, 3, 3, 1)
# Train on 246 samples
# Epoch 1/1000
# 246/246 [==============================] - 5s 19ms/sample - loss: 0.0489
# Epoch 2/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0471
# Epoch 3/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0447
# Epoch 4/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0412
# Epoch 5/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0396
# Epoch 6/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0384
# Epoch 7/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0380
# Epoch 8/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0367
# Epoch 9/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0358
# Epoch 10/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0349
# Epoch 11/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0338
# Epoch 12/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0325
# Epoch 13/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0313
# Epoch 14/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0300
# Epoch 15/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0289
# Epoch 16/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0284
# Epoch 17/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0271
# Epoch 18/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0264
# Epoch 19/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0256
# Epoch 20/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0253
# Epoch 21/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0244
# Epoch 22/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0241
# Epoch 23/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0229
# Epoch 24/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0238
# Epoch 25/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0218
# Epoch 26/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0208
# Epoch 27/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0195
# Epoch 28/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0181
# Epoch 29/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0177
# Epoch 30/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0171
# Epoch 31/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0168
# Epoch 32/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0152
# Epoch 33/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0135
# Epoch 34/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0121
# Epoch 35/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0111
# Epoch 36/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0106
# Epoch 37/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0109
# Epoch 38/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0121
# Epoch 39/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0096
# Epoch 40/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0090
# Epoch 41/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0090
# Epoch 42/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0085
# Epoch 43/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0097
# Epoch 44/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0084
# Epoch 45/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0075
# Epoch 46/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0076
# Epoch 47/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0075
# Epoch 48/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0072
# Epoch 49/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0071
# Epoch 50/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0069
# Epoch 51/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0073
# Epoch 52/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0075
# Epoch 53/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0067
# Epoch 54/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0064
# Epoch 55/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0068
# Epoch 56/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0072
# Epoch 57/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0064
# Epoch 58/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0069
# Epoch 59/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0076
# Epoch 60/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0072
# Epoch 61/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0063
# Epoch 62/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0058
# Epoch 63/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0057
# Epoch 64/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0057
# Epoch 65/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0058
# Epoch 66/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0054
# Epoch 67/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0058
# Epoch 68/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0056
# Epoch 69/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0053
# Epoch 70/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0052
# Epoch 71/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0055
# Epoch 72/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 73/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 74/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0054
# Epoch 75/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0052
# Epoch 76/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0052
# Epoch 77/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0055
# Epoch 78/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0056
# Epoch 79/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0051
# Epoch 80/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0049
# Epoch 81/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0052
# Epoch 82/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0056
# Epoch 83/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 84/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 85/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 86/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 87/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0045
# Epoch 88/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0052
# Epoch 89/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0056
# Epoch 90/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0052
# Epoch 91/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0050
# Epoch 92/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 93/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0047
# Epoch 94/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0046
# Epoch 95/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0046
# Epoch 96/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0044
# Epoch 97/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0050
# Epoch 98/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0056
# Epoch 99/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0046
# Epoch 100/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.
1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 863/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 864/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 865/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 866/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 867/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 868/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 869/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 870/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 871/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 872/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 873/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 874/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0013
# Epoch 875/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 876/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 877/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 878/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 879/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 880/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0010
# Epoch 881/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 882/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 883/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 884/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 885/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 886/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0014
# Epoch 887/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 888/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 889/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 890/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 891/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 892/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 893/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 894/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 895/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 896/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 897/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0013
# Epoch 898/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 899/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 900/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.9661e-04
# Epoch 901/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 902/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 903/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 904/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 905/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 906/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 907/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 908/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 909/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 910/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 911/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 912/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 913/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 914/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 915/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0010
# Epoch 916/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 917/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 918/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 919/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 920/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 921/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 922/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0010
# Epoch 923/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 924/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 925/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.8440e-04
# Epoch 926/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 927/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 928/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9797e-04
# Epoch 929/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 930/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9019e-04
# Epoch 931/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.8911e-04
# Epoch 932/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.5454e-04
# Epoch 933/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.6534e-04
# Epoch 934/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.6782e-04
# Epoch 935/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 936/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0014
# Epoch 937/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 938/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0014
# Epoch 939/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 940/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 941/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 942/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 943/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0013
# Epoch 944/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 945/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 946/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 947/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 948/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 949/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9812e-04
# Epoch 950/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.9831e-04
# Epoch 951/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 952/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0010
# Epoch 953/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.9805e-04
# Epoch 954/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0011
# Epoch 955/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.9621e-04
# Epoch 956/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.5864e-04
# Epoch 957/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.8858e-04
# Epoch 958/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 959/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 960/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.8845e-04
# Epoch 961/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0010
# Epoch 962/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 0.0012
# Epoch 963/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 964/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 965/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0012
# Epoch 966/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 967/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 968/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.7091e-04
# Epoch 969/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.7978e-04
# Epoch 970/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.6649e-04
# Epoch 971/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.4756e-04
# Epoch 972/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.7238e-04
# Epoch 973/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.3392e-04
# Epoch 974/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.5336e-04
# Epoch 975/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.4403e-04
# Epoch 976/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.7460e-04
# Epoch 977/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 978/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0011
# Epoch 979/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.6889e-04
# Epoch 980/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9759e-04
# Epoch 981/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.8674e-04
# Epoch 982/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9459e-04
# Epoch 983/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.8716e-04
# Epoch 984/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 985/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 986/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9857e-04
# Epoch 987/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.8796e-04
# Epoch 988/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 0.0010
# Epoch 989/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.7702e-04
# Epoch 990/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.4207e-04
# Epoch 991/1000
# 246/246 [==============================] - 0s 1ms/sample - loss: 9.7957e-04
# Epoch 992/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.2046e-04
# Epoch 993/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.4042e-04
# Epoch 994/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.7839e-04
# Epoch 995/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.9076e-04
# Epoch 996/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.4900e-04
# Epoch 997/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.3543e-04
# Epoch 998/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.4815e-04
# Epoch 999/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.2541e-04
# Epoch 1000/1000
# 246/246 [==============================] - 0s 2ms/sample - loss: 9.0890e-04
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_54 (ConvLSTM2D) (None, 6, 3, 3, 60)       58800
# _________________________________________________________________
# conv_lst_m2d_55 (ConvLSTM2D) (None, 3, 3, 12)          3504
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 3, 3, 1)           13
# =================================================================
# Total params: 62,317
# Trainable params: 62,317
# Non-trainable params: 0
# _________________________________________________________________
#
# ==========================
# MAE= [2.9883308]
# RMSE =  3.625676059162805
# NMSE =  [0.01951189]
# MAPE= [0.0142466]
# IA= [0.9580776]
# U1= 0.008622600926551446
# U2= 0.5458353885713803
# Running time: 386 seconds
